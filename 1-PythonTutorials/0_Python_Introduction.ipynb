# %% [markdown]
# # Python, Anaconda Installation
#
# In this tutorial, we show the installation process of Anaconda and Jupyter Notebook for running Python code.

# %% [markdown]
# # Install Anaconda Navigator and Python
#
# 1.	Download for Windows: https://www.anaconda.com/products/distribution#Downloads
# 2.	Follow the installation steps.

# %% [markdown]
# # Use Anaconda Prompt – Conda Environment
#
# For more information: https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html
#
# 1.	Open Anaconda Prompt (terminal)
# 2.	Create conda environment
#
#     `conda create --name EyeTrakingEnv python`
#
# 3.	Activate conda environment
#
#     `conda activate EyeTrakingEnv`
#
# 4. Install jupyter notebook
#
#     `conda install -c anaconda jupyter`
#
# 5. Run jupyter notebook
#
#     `jupyter notebook`

# %% [markdown]
# ## Print Hello World

# %%
print('Hello World')

# %% [markdown]
# ## Import Libraries
#
# Firstly, you need to install libraries into the Conda environment.
#
# 1. Open a Anaconda Prompt terminal window.
#
# 2. Activate conda environment.
#
#     `conda activate EyeTrakingEnv`
#
# 3. Google: "conda install "library name" " (For example: conda install numpy)
#
# 4. Go to "anaconda.org" and copy the command. (Hint: If you cannot find the library on "anaconda.org", you can search for it on Google using the query "pip install "library name" ", and then use the pip command in the same way.)"

# %% [markdown]
# ![sc2.png](data:image/png;base64,...)

# %% [markdown]
# 5. Run this command on Anaconda
#
#     `conda install -c anaconda numpy`
#
# ```
# # Bu, kod olarak biçimlendirilmiştir
# ```

# %%
import numpy

# %% [markdown]
# ## Command Prompt Basics
#
# ### List folders in current dictionary
#
#     `dir`
#
# ### Open a dictionary
#
#     `cd Desktop`
#
# ### Go to parent dictionary
#
#     `cd ..`
